# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Some example data to display
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('sin(x) and sin(-x)')
ax1.plot(x, y, "tab:green")
ax2.plot(x, -y, "tab:orange")

# %%
y_ = x ** np.sin(x ** 2)

# %%
fig_, axs_ = plt.subplots(2)
fig_.suptitle('xsin(x) and -xsin(-x)')
axs_[0].plot(x, y_, 'tab:purple')
axs_[1].plot(x, -y_, 'tab:pink')

# %%
import panel as pn
pn.extension()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# <div id='ebad9079-4e19-4d12-8846-23d9f1e9eac4'>
#   <div id="eec750a8-929b-4f47-b4a3-9eb8ade1d7e1" data-root-id="ebad9079-4e19-4d12-8846-23d9f1e9eac4" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
tabs = pn.Tabs(('Scatter 1', fig),("Scatter 2", fig_))
tabs_1 = pn.Tabs(('Scatter 1', fig),("Scatter 2", fig_))

# %%
tabs
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'ac2b624a-03f3-46f4-98d7-2fe0d028dc04': {'version…

# %%
template = pn.template.FastListTemplate(
    title='Tabs & Subplot example', 
    main=[pn.Row(tabs, tabs_1)],
    accent_base_color="#87d8b1",
    header_background="#0001bc",
)
template.show()
template.servable();
# Out:
# Launching server at http://localhost:39779
